# %%
import ecco
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import ecco
#
# ModuleNotFoundError: No module named 'ecco'

# %%
# !pip install ecco --no-deps

# %%
import ecco
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import ecco
#
# ModuleNotFoundError: No module named 'ecco'
