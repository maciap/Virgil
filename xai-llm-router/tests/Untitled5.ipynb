# %%
from polyjuice import Polyjuice
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from polyjuice import Polyjuice
#
# ModuleNotFoundError: No module named 'polyjuice'

# %%
import sys
print(sys.executable)
print(sys.path)

# %%
try:
    import polyjuice
    print("polyjuice imported:", polyjuice)
except Exception as e:
    import traceback
    traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\marti\AppData\Local\Temp\ipykernel_137136\265345175.py", line 2, in <module>
#     import polyjuice
# ModuleNotFoundError: No module named 'polyjuice'

# %%
try:
    from polyjuice import Polyjuice
    print("Polyjuice class imported successfully")
except Exception as e:
    import traceback
    traceback.print_exc()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\marti\AppData\Local\Temp\ipykernel_137136\1225547810.py", line 2, in <module>
#     from polyjuice import Polyjuice
# ModuleNotFoundError: No module named 'polyjuice'

# %%
import sys
print(sys.executable)

import importlib.util
print(importlib.util.find_spec("polyjuice"))
# Out:
# C:\Users\marti\XAI4LLMsMetaToolkit\xai-llm-router\mynev4\Scripts\python.exe
# None
